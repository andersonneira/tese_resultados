# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import classification_report
from sklearn.cluster import KMeans
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.decomposition import FastICA
from announce import *

# %%
early_warning_url = "data_exp_4.csv"
early_warning = pd.read_csv(early_warning_url, sep=";")
early_warning
# Out:
#      10_kurt_maior_pacote  10_skw_total_ips_destino  \
# 140                   NaN                       NaN
# 141                   NaN                       NaN
# 142                   NaN                       NaN
# 143             18.673341                -11.754969
# 144             18.893231                  0.315009
# ..                    ...                       ...
# 315              3.098795                  0.218835
# 316              3.098795                  0.239141
# 317              3.129972                  0.239600
# 318              3.129972                  0.217385
# 319              3.272131                  0.217442
#
#      10_coefficient_variation_total_ips_origem  has_bot
# 140                                        NaN        0
# 141                                        NaN        0
# 142                                        NaN        0
# 143                                   0.167179        0
# 144                                   0.167448        0
# ..                                         ...      ...
# 315                                   0.235815        1
# 316                                   0.235763        1
# 317                                   0.236957        1
# 318                                   0.236714        1
# 319                                   0.236430        1
#
# [180 rows x 4 columns]

# %%
from mpl_toolkits.mplot3d.proj3d import proj_transform
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib.text import Annotation

class Annotation3D(Annotation):

    def __init__(self, text, xyz, *args, **kwargs):
        super().__init__(text, xy=(0, 0), *args, **kwargs)
        self._xyz = xyz

    def draw(self, renderer):
        x2, y2, z2 = proj_transform(*self._xyz, self.axes.M)
        self.xy = (x2, y2)
        super().draw(renderer)
        
def _annotate3D(ax, text, xyz, *args, **kwargs):
    '''Add anotation `text` to an `Axes3d` instance.'''

    annotation = Annotation3D(text, xyz, *args, **kwargs)
    ax.add_artist(annotation)

setattr(Axes3D, 'annotate3D', _annotate3D)

# %% [markdown]
# # Avaliação 1

# %%
colunas = ['10_kurt_maior_pacote', '10_skw_total_ips_destino', '10_coefficient_variation_total_ips_origem' ]
init = 241
limit = 321
x_train = early_warning[colunas].copy()[init:limit]
y_real = early_warning['has_bot'][init:limit]
#x_train = x_train.fillna(0)
clustering = KMeans(n_clusters=2, random_state=0).fit(x_train)    
y_test = clustering.labels_
print(confusion_matrix(y_real, y_test))
print(classification_report(y_real, y_test, digits=4))
# Out:
# [[60  0]
#  [ 0 20]]
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        60
#            1     1.0000    1.0000    1.0000        20
#
#     accuracy                         1.0000        80
#    macro avg     1.0000    1.0000    1.0000        80
# weighted avg     1.0000    1.0000    1.0000        80

# %%
colunas = ['10_kurt_maior_pacote', '10_skw_total_ips_destino', '10_coefficient_variation_total_ips_origem',
           'has_bot']
          
dataframe = early_warning[colunas][init:limit]
dataframe['y_test'] = y_test
df1= dataframe.query('has_bot == 0')                                
df2= dataframe.query('has_bot == 1')  

plt.clf()

fig2 = plt.figure(figsize = (9, 9))
ax2 = plt.axes(projection ="3d")
font_size = 22


ax2.xaxis.set_tick_params(labelsize=font_size)
ax2.yaxis.set_tick_params(labelsize=font_size)
ax2.zaxis.set_tick_params(labelsize=font_size)
c = [ "blue" if i == 0 else "red" for i in y_test]

font_size_group = 20
ax2.annotate3D('Grupo 1',  (36.3, 0.273, -5.4),
              xytext=(0, -60),
              fontsize = font_size_group,
              textcoords='offset points',
              bbox=dict(boxstyle="round", fc="lightyellow"),
              arrowprops=dict(arrowstyle="-|>", ec='black', fc='white', lw=3))

ax2.annotate3D('Grupo 1', (40, 0.27, -12.5),
              xytext=(0, 60),
              fontsize = font_size_group,
              textcoords='offset points',
              bbox=dict(boxstyle="round", fc="lightyellow"),
              arrowprops=dict(arrowstyle="-|>", ec='black', fc='white', lw=3))


ax2.annotate3D('Grupo 2', (38, 0.222, 5.3),
              xytext=(30, -60),
              fontsize = font_size_group,
              textcoords='offset points',
              bbox=dict(boxstyle="round", fc="lightyellow"),
              arrowprops=dict(arrowstyle="-|>", ec='black', fc='white', lw=3))


ax2.set_xlabel('\n\nKurtosis do maior pacote', fontsize=font_size) 
ax2.set_ylabel('\n\n\nCV do total de \n IPs de origem', fontsize=font_size) 
ax2.set_zlabel('\n\nSkewness do total de \n IPs de destino', fontsize=font_size)

ax2.plot(df1[colunas[0]], df1[colunas[2]],df1[colunas[1]] , "o", label="Ciclo normal", c='blue')
ax2.plot(df2[colunas[0]], df2[colunas[2]],df2[colunas[1]] , "^", label="Ciclo malicioso", c='red')

fig2.legend(loc="upper center",prop={'size': font_size})
plt.savefig("original.pdf")
plt.show()
plt.clf()

# %%
df1= dataframe.query('y_test == 0')                                
df2= dataframe.query('y_test == 1')  

fig2 = plt.figure(figsize = (9, 9))
ax2 = plt.axes(projection ="3d")

ax2.xaxis.set_tick_params(labelsize=font_size)
ax2.yaxis.set_tick_params(labelsize=font_size)
ax2.zaxis.set_tick_params(labelsize=font_size)
c = [ "blue" if i == 0 else "red" for i in y_test]

ax2.set_xlabel('\n\nKurtosis do maior pacote', fontsize=font_size) 
ax2.set_ylabel('\n\n\nCV do total de \n IPs de origem', fontsize=font_size) 
ax2.set_zlabel('\n\nSkewness do total de \n IPs de destino', fontsize=font_size)

font_size_group = 20
ax2.annotate3D('Grupo 1',  (36.3, 0.273, -5.4),
              xytext=(0, -60),
              fontsize = font_size_group,
              textcoords='offset points',
              bbox=dict(boxstyle="round", fc="lightyellow"),
              arrowprops=dict(arrowstyle="-|>", ec='black', fc='white', lw=3))

ax2.annotate3D('Grupo 1', (40, 0.27, -12.5),
              xytext=(0, 60),
              fontsize = font_size_group,
              textcoords='offset points',
              bbox=dict(boxstyle="round", fc="lightyellow"),
              arrowprops=dict(arrowstyle="-|>", ec='black', fc='white', lw=3))


ax2.annotate3D('Grupo 2', (38, 0.222, 5.3),
              xytext=(30, -60),
              fontsize = font_size_group,
              textcoords='offset points',
              bbox=dict(boxstyle="round", fc="lightyellow"),
              arrowprops=dict(arrowstyle="-|>", ec='black', fc='white', lw=3))

ax2.plot(df1[colunas[0]], df1[colunas[2]],df1[colunas[1]] , "o", label="Ciclo normal", c='blue')
ax2.plot(df2[colunas[0]], df2[colunas[2]],df2[colunas[1]] , "^", label="Ciclo malicioso", c='red')

fig2.legend(loc="upper center",prop={'size': font_size})

plt.savefig("cluster.pdf")
plt.show()

# %%
colunas = ['maior_pacote', 'total_ips_destino', 'total_ips_origem',
           'has_bot']
          
dataframe = early_warning[colunas][init:limit]
dataframe['y_test'] = y_test
df1= dataframe.query('has_bot == 0')                                
df2= dataframe.query('has_bot == 1')  

plt.clf()

fig2 = plt.figure(figsize = (11,11))
ax2 = plt.axes(projection ="3d")
font_size = 22
ax2.xaxis.set_tick_params(labelsize=font_size)
ax2.yaxis.set_tick_params(labelsize=font_size)
ax2.zaxis.set_tick_params(labelsize=font_size)
c = [ "blue" if i == 0 else "red" for i in y_test]


ax2.set_xlabel('\n\nMaior pacote', fontsize=font_size) 
ax2.set_ylabel('\n\nTotal de \n IPs de origem', fontsize=font_size) 
ax2.set_zlabel('\n\n\n\nTotal de \n IPs de destino', fontsize=font_size)
               
font_size_group = 20

ax2.plot(df1[colunas[0]], df1[colunas[2]],df1[colunas[1]] , "o", label="Ciclo normal", c='blue')
ax2.plot(df2[colunas[0]], df2[colunas[2]],df2[colunas[1]] , "^", label="Ciclo malicioso", c='red')
fig2.legend(loc="upper center",prop={'size': font_size})
plt.savefig("sem_esap.pdf")
plt.show()
plt.clf()

# %% [markdown]
# # Avaliação 2

# %%
colunas = ['10_kurt_maior_pacote', '10_skw_total_ips_destino', '10_coefficient_variation_total_ips_origem' ]
init = 241
limit = 321
x_train = early_warning[colunas].copy()[init:limit]
y_real = early_warning['has_bot'][init:limit]
resultado2 = announce(x_train)
pd.set_option('display.max_rows', resultado2.shape[0]+1)
resultado2.to_csv('resultado_teste_padrao_exp_4.csv', sep=";")
resultado2
# Out:
#                                             Algorithm      mean  \
# 0                SOM(m=2, n=1, dim=3, random_state=0)  0.960134
# 1         KMeans(n_clusters=2, random_state=0, tol=1)  0.960134
# 2       KMeans(n_clusters=2, random_state=0, tol=0.1)  0.960134
# 3      KMeans(n_clusters=2, random_state=0, tol=0.01)  0.960134
# 4     KMeans(n_clusters=2, random_state=0, tol=0.001)  0.960134
# 5                KMeans(n_clusters=2, random_state=0)  0.960134
# 6   KMeans(algorithm='elkan', n_clusters=2, random...  0.960134
# 7   KMeans(algorithm='elkan', n_clusters=2, random...  0.960134
# 8   KMeans(algorithm='elkan', n_clusters=2, random...  0.960134
# 9   KMeans(algorithm='elkan', n_clusters=2, random...  0.960134
# 10  KMeans(algorithm='elkan', n_clusters=2, random...  0.960134
# 11    GaussianMixture(n_components=2, random_state=0)  0.960134
# 12  GaussianMixture(init_params='random_from_data'...  0.960134
# 13  GaussianMixture(init_params='k-means++', n_com...  0.960134
# 14  GaussianMixture(covariance_type='tied', n_comp...  0.960134
# 15  GaussianMixture(covariance_type='spherical', n...  0.960134
# 16  GaussianMixture(covariance_type='diag', n_comp...  0.960134
# 17  BisectingKMeans(init='k-means++', n_clusters=2...  0.960134
# 18  BisectingKMeans(bisecting_strategy='largest_cl...  0.960134
# 19  BisectingKMeans(algorithm='elkan', init='k-mea...  0.960134
# 20                 Birch(n_clusters=2, threshold=0.3)  0.960134
# 21                          AgglomerativeClustering()  0.960134
# 22                                        MeanShift()  0.793892
# 23                                           DBSCAN()  0.529622
# 24                 Birch(n_clusters=2, threshold=0.7)  0.517004
# 25                 Birch(n_clusters=2, threshold=0.6)  0.517004
# 26                 Birch(n_clusters=2, threshold=0.4)  0.517004
# 27                                Birch(n_clusters=2)  0.517004
# 28          AgglomerativeClustering(linkage='single')  0.517004
# 29        AgglomerativeClustering(linkage='complete')  0.517004
# 30         AgglomerativeClustering(linkage='average')  0.517004
# 31                                           OPTICS()  0.362036
# 32  GaussianMixture(init_params='random', n_compon...  0.327306
# 33                        HDBSCAN(min_cluster_size=2)  0.306856
# 34  HDBSCAN(cluster_selection_method='leaf', min_c...  0.306856
# 35      BisectingKMeans(n_clusters=2, random_state=0)  0.207261
# 36  BisectingKMeans(bisecting_strategy='largest_cl...  0.207261
#
#     Calinski_harabasz_score_minmax  Silhouette_score_minmax  CDBW_minmax  \
# 0                         0.881138                 1.000000     1.000000
# 1                         0.881138                 1.000000     1.000000
# 2                         0.881138                 1.000000     1.000000
# 3                         0.881138                 1.000000     1.000000
# 4                         0.881138                 1.000000     1.000000
# 5                         0.881138                 1.000000     1.000000
# 6                         0.881138                 1.000000     1.000000
# 7                         0.881138                 1.000000     1.000000
# 8                         0.881138                 1.000000     1.000000
# 9                         0.881138                 1.000000     1.000000
# 10                        0.881138                 1.000000     1.000000
# 11                        0.881138                 1.000000     1.000000
# 12                        0.881138                 1.000000     1.000000
# 13                        0.881138                 1.000000     1.000000
# 14                        0.881138                 1.000000     1.000000
# 15                        0.881138                 1.000000     1.000000
# 16                        0.881138                 1.000000     1.000000
# 17                        0.881138                 1.000000     1.000000
# 18                        0.881138                 1.000000     1.000000
# 19                        0.881138                 1.000000     1.000000
# 20                        0.881138                 1.000000     1.000000
# 21                        0.881138                 1.000000     1.000000
# 22                        1.000000                 0.995189     0.000000
# 23                        0.232497                 0.494706     0.007676
# 24                        0.000000                 0.590181     0.000000
# 25                        0.000000                 0.590181     0.000000
# 26                        0.000000                 0.590181     0.000000
# 27                        0.000000                 0.590181     0.000000
# 28                        0.000000                 0.590181     0.000000
# 29                        0.000000                 0.590181     0.000000
# 30                        0.000000                 0.590181     0.000000
# 31                        0.011911                 0.040345     0.002130
# 32                        0.003143                 0.250488     0.000153
# 33                        0.001290                 0.596794     0.000000
# 34                        0.001290                 0.596794     0.000000
# 35                        0.063989                 0.000000     0.000481
# 36                        0.063989                 0.000000     0.000481
#
#     Davies_bouldin_score_minmax_normalizado  SDBW_minmax_normalizado  \
# 0                              9.980213e-01             9.215098e-01
# 1                              9.980213e-01             9.215098e-01
# 2                              9.980213e-01             9.215098e-01
# 3                              9.980213e-01             9.215098e-01
# 4                              9.980213e-01             9.215098e-01
# 5                              9.980213e-01             9.215098e-01
# 6                              9.980213e-01             9.215098e-01
# 7                              9.980213e-01             9.215098e-01
# 8                              9.980213e-01             9.215098e-01
# 9                              9.980213e-01             9.215098e-01
# 10                             9.980213e-01             9.215098e-01
# 11                             9.980213e-01             9.215098e-01
# 12                             9.980213e-01             9.215098e-01
# 13                             9.980213e-01             9.215098e-01
# 14                             9.980213e-01             9.215098e-01
# 15                             9.980213e-01             9.215098e-01
# 16                             9.980213e-01             9.215098e-01
# 17                             9.980213e-01             9.215098e-01
# 18                             9.980213e-01             9.215098e-01
# 19                             9.980213e-01             9.215098e-01
# 20                             9.980213e-01             9.215098e-01
# 21                             9.980213e-01             9.215098e-01
# 22                             1.000000e+00             9.742699e-01
# 23                             9.686755e-01             9.445570e-01
# 24                             9.948388e-01             1.000000e+00
# 25                             9.948388e-01             1.000000e+00
# 26                             9.948388e-01             1.000000e+00
# 27                             9.948388e-01             1.000000e+00
# 28                             9.948388e-01             1.000000e+00
# 29                             9.948388e-01             1.000000e+00
# 30                             9.948388e-01             1.000000e+00
# 31                             9.309970e-01             8.247965e-01
# 32                             9.169694e-01             4.657747e-01
# 33                             1.110223e-16             9.361953e-01
# 34                             1.110223e-16             9.361953e-01
# 35                             9.718322e-01             1.110223e-16
# 36                             9.718322e-01             1.110223e-16
#
#     Calinski_harabasz_score  Silhouette_score  Davies_bouldin_score      SDBW  \
# 0                337.525145          0.855268              0.167035  0.140136
# 1                337.525145          0.855268              0.167035  0.140136
# 2                337.525145          0.855268              0.167035  0.140136
# 3                337.525145          0.855268              0.167035  0.140136
# 4                337.525145          0.855268              0.167035  0.140136
# 5                337.525145          0.855268              0.167035  0.140136
# 6                337.525145          0.855268              0.167035  0.140136
# 7                337.525145          0.855268              0.167035  0.140136
# 8                337.525145          0.855268              0.167035  0.140136
# 9                337.525145          0.855268              0.167035  0.140136
# 10               337.525145          0.855268              0.167035  0.140136
# 11               337.525145          0.855268              0.167035  0.140136
# 12               337.525145          0.855268              0.167035  0.140136
# 13               337.525145          0.855268              0.167035  0.140136
# 14               337.525145          0.855268              0.167035  0.140136
# 15               337.525145          0.855268              0.167035  0.140136
# 16               337.525145          0.855268              0.167035  0.140136
# 17               337.525145          0.855268              0.167035  0.140136
# 18               337.525145          0.855268              0.167035  0.140136
# 19               337.525145          0.855268              0.167035  0.140136
# 20               337.525145          0.855268              0.167035  0.140136
# 21               337.525145          0.855268              0.167035  0.140136
# 22               381.410005          0.853306              0.126365  0.053801
# 23                98.040547          0.649148              0.770217  0.102422
# 24                12.200202          0.688095              0.232449  0.011697
# 25                12.200202          0.688095              0.232449  0.011697
# 26                12.200202          0.688095              0.232449  0.011697
# 27                12.200202          0.688095              0.232449  0.011697
# 28                12.200202          0.688095              0.232449  0.011697
# 29                12.200202          0.688095              0.232449  0.011697
# 30                12.200202          0.688095              0.232449  0.011697
# 31                16.597806          0.463805              1.544670  0.298395
# 32                13.360546          0.549527              1.832998  0.885887
# 33                12.676543          0.690792             20.680625  0.116105
# 34                12.676543          0.690792             20.680625  0.116105
# 35                35.825546          0.447348              0.705334  1.648067
# 36                35.825546          0.447348              0.705334  1.648067
#
#          CDBW  Davies_bouldin_score_minmax  SDBW_minmax
# 0   11.865856                     0.001979     0.078490
# 1   11.865856                     0.001979     0.078490
# 2   11.865856                     0.001979     0.078490
# 3   11.865856                     0.001979     0.078490
# 4   11.865856                     0.001979     0.078490
# 5   11.865856                     0.001979     0.078490
# 6   11.865856                     0.001979     0.078490
# 7   11.865856                     0.001979     0.078490
# 8   11.865856                     0.001979     0.078490
# 9   11.865856                     0.001979     0.078490
# 10  11.865856                     0.001979     0.078490
# 11  11.865856                     0.001979     0.078490
# 12  11.865856                     0.001979     0.078490
# 13  11.865856                     0.001979     0.078490
# 14  11.865856                     0.001979     0.078490
# 15  11.865856                     0.001979     0.078490
# 16  11.865856                     0.001979     0.078490
# 17  11.865856                     0.001979     0.078490
# 18  11.865856                     0.001979     0.078490
# 19  11.865856                     0.001979     0.078490
# 20  11.865856                     0.001979     0.078490
# 21  11.865856                     0.001979     0.078490
# 22   0.000000                     0.000000     0.025730
# 23   0.091083                     0.031325     0.055443
# 24   0.000000                     0.005161     0.000000
# 25   0.000000                     0.005161     0.000000
# 26   0.000000                     0.005161     0.000000
# 27   0.000000                     0.005161     0.000000
# 28   0.000000                     0.005161     0.000000
# 29   0.000000                     0.005161     0.000000
# 30   0.000000                     0.005161     0.000000
# 31   0.025270                     0.069003     0.175203
# 32   0.001812                     0.083031     0.534225
# 33   0.000000                     1.000000     0.063805
# 34   0.000000                     1.000000     0.063805
# 35   0.005713                     0.028168     1.000000
# 36   0.005713                     0.028168     1.000000

# %%
print(resultado2['Algorithm'][0])
clustering = eval(resultado2['Algorithm'][0])
clustering.fit(format_data(x_train))
print(confusion_matrix(y_real, y_test))
print(classification_report(y_real, y_test, digits=4))
y_test = [0 if i == 1 else 1 for i in y_test]
# Out:
# SOM(m=2, n=1, dim=3, random_state=0)
# [[60  0]
#  [ 0 20]]
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        60
#            1     1.0000    1.0000    1.0000        20
#
#     accuracy                         1.0000        80
#    macro avg     1.0000    1.0000    1.0000        80
# weighted avg     1.0000    1.0000    1.0000        80

# %% [markdown]
# # Avaliação 3

# %%
cols = early_warning.columns[361:]
print(cols)
init = 241
limit = 321
x_train_novo = early_warning[cols].copy()[init:limit]
y_real_novo = early_warning['has_bot'][init:limit]
x_train_novo = x_train_novo.fillna(0)
# Out:
# Index(['10_skw_total_pacotes', '10_kurt_total_pacotes',
#        '10_coefficient_variation_total_pacotes', '10_lag-1AC_total_pacotes',
#        '10_lag-2AC_total_pacotes', '10_lag-3AC_total_pacotes',
#        '10_skw_total_pacotes_icmp', '10_kurt_total_pacotes_icmp',
#        '10_coefficient_variation_total_pacotes_icmp',
#        '10_lag-1AC_total_pacotes_icmp',
#        ...
#        '10_coefficient_variation_std_tcp_time_relative',
#        '10_lag-1AC_std_tcp_time_relative', '10_lag-2AC_std_tcp_time_relative',
#        '10_lag-3AC_std_tcp_time_relative', '10_skw_mean_tcp_time_relative',
#        '10_kurt_mean_tcp_time_relative',
#        '10_coefficient_variation_mean_tcp_time_relative',
#        '10_lag-1AC_mean_tcp_time_relative',
#        '10_lag-2AC_mean_tcp_time_relative',
#        '10_lag-3AC_mean_tcp_time_relative'],
#       dtype='object', length=306)

# %%
pca = FastICA(n_components=5).fit(x_train_novo)
novo  = pca.transform(x_train_novo)

# %%
resultado3 = announce(pd.DataFrame(novo),number_clusters=2,cluster_validity_metric = 'cdbw')
pd.set_option('display.max_rows', resultado3.shape[0]+1)
resultado3.to_csv("resultado_fs_exp_4.csv", sep=";")
resultado3
# Out:
#                                             Algorithm      cdbw
# 0         KMeans(n_clusters=2, random_state=0, tol=1)  0.185849
# 1       KMeans(n_clusters=2, random_state=0, tol=0.1)  0.185849
# 2      KMeans(n_clusters=2, random_state=0, tol=0.01)  0.185849
# 3     KMeans(n_clusters=2, random_state=0, tol=0.001)  0.185849
# 4                KMeans(n_clusters=2, random_state=0)  0.185849
# 5   KMeans(algorithm='elkan', n_clusters=2, random...  0.185849
# 6   KMeans(algorithm='elkan', n_clusters=2, random...  0.185849
# 7   KMeans(algorithm='elkan', n_clusters=2, random...  0.185849
# 8   KMeans(algorithm='elkan', n_clusters=2, random...  0.185849
# 9   KMeans(algorithm='elkan', n_clusters=2, random...  0.185849
# 10                 Birch(n_clusters=2, threshold=0.7)  0.145425
# 11                 Birch(n_clusters=2, threshold=0.6)  0.145425
# 12                 Birch(n_clusters=2, threshold=0.4)  0.145425
# 13                 Birch(n_clusters=2, threshold=0.3)  0.145425
# 14                                Birch(n_clusters=2)  0.145425
# 15        AgglomerativeClustering(linkage='complete')  0.145425
# 16         AgglomerativeClustering(linkage='average')  0.145425
# 17          AgglomerativeClustering(linkage='single')  0.117905
# 18               SOM(m=2, n=1, dim=5, random_state=0)  0.096335
# 19    GaussianMixture(n_components=2, random_state=0)  0.091732
# 20  GaussianMixture(init_params='k-means++', n_com...  0.091732
# 21  GaussianMixture(covariance_type='tied', n_comp...  0.091732
# 22  GaussianMixture(covariance_type='diag', n_comp...  0.091732
# 23      BisectingKMeans(n_clusters=2, random_state=0)  0.091732
# 24  BisectingKMeans(init='k-means++', n_clusters=2...  0.091732
# 25  BisectingKMeans(bisecting_strategy='largest_cl...  0.091732
# 26  BisectingKMeans(bisecting_strategy='largest_cl...  0.091732
# 27  BisectingKMeans(algorithm='elkan', init='k-mea...  0.091732
# 28                          AgglomerativeClustering()  0.091732
# 29  GaussianMixture(init_params='random_from_data'...  0.056538
# 30  GaussianMixture(covariance_type='spherical', n...  0.043365
# 31  GaussianMixture(init_params='random', n_compon...  0.021454
# 32                                           OPTICS()  0.000000
# 33                                        MeanShift()  0.000000
# 34                        HDBSCAN(min_cluster_size=2)  0.000000
# 35  HDBSCAN(cluster_selection_method='leaf', min_c...  0.000000
# 36                                           DBSCAN()  0.000000

# %%
print(resultado3['Algorithm'][0]) 
clustering = eval(resultado3['Algorithm'][0]) 
y_test = clustering.fit_predict(novo)  
print(confusion_matrix(y_real_novo, y_test)) 
print(classification_report(y_real_novo, y_test, digits=6))
# Out:
# KMeans(n_clusters=2, random_state=0, tol=1)
# [[60  0]
#  [ 0 20]]
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000        60
#            1   1.000000  1.000000  1.000000        20
#
#     accuracy                       1.000000        80
#    macro avg   1.000000  1.000000  1.000000        80
# weighted avg   1.000000  1.000000  1.000000        80
